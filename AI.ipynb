# %%
while True:
    message = input("\nYou: ").lower()

    if message == "quit":
        print("Bot: Chat ended.")
        break

    elif message == "yo":
        print("Bot: Wsp, gng?")

    elif message == "i need your help vro":
        print("Bot: Sure thing, what's up?")

    elif message == "how do i get a valentine":
        print("Bot: IDK, vro ✌️😭")

    elif message == "you said you'd help me":
        print("Bot: Nahhhh, you on your own, gng 😂😂😂")

    else:
        print("Bot: I don't understand that.")
# Out:
# Bot: Wsp, gng?
# Bot: Sure thing, what's up?
# Bot: IDK, vro ✌️😭
# Bot: Nahhhh, you on your own, gng 😂😂😂
# Bot: Chat ended.
